# %%
from w2_control_file import W2ControlFile
import w2_functions as w2

w2con = W2ControlFile('w2_con.npt')
w2con.save()
# Out:
# out_filepath:  /Users/todd/GitHub/environmentalsystems/CE-QUAL-W2_dev/utilities/W2ParserPython/src/w2parser/w2_con.npt

# %%
infile = os.path.abspath('w2_con.npt')
nlines = 969
record_line = 15 # line number of header of record in w2_con.npt file
record_nlines = 3 # number of lines in record, including the blank line after the record
widths = 7*[8]

data = w2.get_record(infile, widths, nlines, record_line, record_nlines)
data
# Out:
#    GRID  NWB  NBR  IMX  KMX  NPROC CLOSEC
# 0   NaN    1    1   77   56      1     ON

# %%
infile = os.path.abspath('w2_con.npt')
nlines = 969
record_line = 208 # line number of header of record in w2_con.npt file
record_nlines = 21 # number of lines in record, including the blank line after the record
widths = 8*[8]

data = w2.get_record(infile, widths, nlines, record_line, record_nlines)
data
# Out:
#    GATE GAS GASGTC  EQGT  AGASGT  BGASGT  CGASGT GTTYPE  SPBC
# 0     POWR1    OFF     2   135.0   -35.0    -0.1    POW   NaN
# 1       SB1     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 2       SB2     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 3       SB3     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 4       SB4     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 5       SB5     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 6       SB6     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 7       SB7     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 8       SB8     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 9       SB9     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 10     SB10     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 11     SB11     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 12     SB12     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 13     SB13     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 14     SB14     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 15     SB15     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 16     SB16     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 17     SB17     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 18     SB18     ON     2   135.0   -35.0    -0.1    SPB  2.04
# 19    OTHER    OFF     2   135.0   -35.0    -0.1    NaN   NaN

# %%
infile = os.path.abspath('w2_con.npt')
nlines = 969
record_line = 337 # line number of header of record in w2_con.npt file
record_nlines = 11 # number of lines in record, including the blank line after the record
widths = 10*[8]

data = w2.get_record(infile, widths, nlines, record_line, record_nlines)
display(data)
data2 = w2.reshape_wrapped_fields(data, int)
display(data2)
# Out:
#   SPR SEG  ISPR  ISPR.1  ISPR.2  ISPR.3  ISPR.4  ISPR.5  ISPR.6  ISPR.7  \
# 0    WB 1     2       3       4     5.0     6.0     7.0     8.0     9.0
# 1     NaN    11      12      13    14.0    15.0    16.0    17.0    18.0
# 2     NaN    20      21      22    23.0    24.0    25.0    26.0    27.0
# 3     NaN    29      30      31    32.0    33.0    34.0    35.0    36.0
# 4     NaN    38      39      40    41.0    42.0    43.0    44.0    45.0
# 5     NaN    47      48      49    50.0    51.0    52.0    53.0    54.0
# 6     NaN    56      57      58    59.0    60.0    61.0    62.0    63.0
# 7     NaN    65      66      67    68.0    69.0    70.0    71.0    72.0
# 8     NaN    74      75      76     NaN     NaN     NaN     NaN     NaN
#
#    ISPR.8
# 0    10.0
# 1    19.0
# 2    28.0
# 3    37.0
# 4    46.0
# 5    55.0
# 6    64.0
# 7    73.0
# 8     NaN
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /var/folders/ll/ws3kw_mj79v31gkp6r5x_4dm0000gn/T/ipykernel_94490/1873382185.py in <module>
#       7 data = w2.get_record(infile, widths, nlines, record_line, record_nlines)
#       8 display(data)
# ----> 9 data2 = w2.reshape_wrapped_fields(data, int)
#      10 display(data2)
#
# ~/GitHub/environmentalsystems/CE-QUAL-W2_dev/utilities/W2ParserPython/src/w2parser/w2_functions.py in reshape_wrapped_fields(data, data_type)
#      20         # Make sure the data type of all the columns is correct
#      21         convert_dict = {field_name: data_type}
# ---> 22         data2 = data2.astype(convert_dict)
#      23         data2 = data2.dropna(axis=1)
#      24         # Append the first field back to the data frame if all of the fields were empty and therefore were removed by dropna
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5797                 if col_name in dtype:
#    5798                     results.append(
# -> 5799                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5800                     )
#    5801                 else:
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# ~/opt/miniconda3/envs/clearwater/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1211     """
#    1212     if not np.isfinite(values).all():
# -> 1213         raise IntCastingNaNError(
#    1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
infile = os.path.abspath('w2_con.npt')
nlines = 969
record_line = 319 # line number of header of record in w2_con.npt file
record_nlines = 3 # number of lines in record, including the blank line after the record
widths = 10*[8]
data = w2.get_record(infile, widths, nlines, record_line, record_nlines)
data2 = w2.reshape_wrapped_fields(data, float)
data2
# Out:
#   PRF DATE  PRFD
# 0     WB 1   NaN
