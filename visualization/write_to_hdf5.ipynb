# %% [markdown]
#  # CE-QUAL-W2 Data Visualization Demo

# %%
import w2

# %%
data_columns = [
    'Air Temperature',
    'Dew Point Temperature',
    'Wind Speed',
    'Wind Direction',
    'Cloudiness',
    'Solar Radiation'
]

ylabels = [
    'Air Temperature ($^oC$)',
    'Dew Point Temperature ($^oC$)',
    'Wind Speed (m/s)',
    'Wind Direction (radians)',
    'Cloudiness (fraction)',
    'Solar Radiation ($W/m^2$)'
]

met_wb1 = w2.read('BerlinMilton2006/2006_Met.npt', 2006, data_columns)
met_wb1 = w2.read('BerlinMilton2006/2006_Met.npt', 2006, data_columns)
w2.write_hdf(met_wb1, 'berlin_2006.h5', 'input/met_wb1')
